# %%
pip install vk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vk in /usr/local/lib/python3.7/dist-packages (3.0)
# Requirement already satisfied: requests~=2.24 in /usr/local/lib/python3.7/dist-packages (from vk) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests~=2.24->vk) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests~=2.24->vk) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests~=2.24->vk) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests~=2.24->vk) (1.24.3)

# %%
import vk
#import webbrowser
from vk.session import requests
import json

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
import networkx as nx

# %%
import copy

# %%
#https://oauth.vk.com/authorize?client_id=51445002&scope=friends&redirect_uri=https://oauth.vk.com/blank.html&display=page&response_type=token&revoke=1#
#https://oauth.vk.com/authorize?client_id=51445002&scope=messages&redirect_uri=https://oauth.vk.com/blank.html&display=page&response_type=token&revoke=1#

# %%
token = "08df9c4e08df9c4e08df9c4e590bcf6144008df08df9c4e6b9d251ac1eb712049096851"
version = 5.126
user_id = 113001678

# %%
def myfunction(datafunc, user_idfunc, framefunc): #Функция преобразования полученный данных формата JSON в DataFrame
  i = 0
  while count > i:
    main_id = user_idfunc #ID человека чьих друзей парсят
    id_friend = datafunc[i]['id'] #id его друзей
    first_name = datafunc[i]['first_name']#Имя 
    last_name =  datafunc[i]['last_name']#Фамилия
    new_row = {'main_id': main_id, 'id_friend': id_friend,'first_name': first_name, 'last_name': last_name}#Создаем строку с помощью которой записываем данные в DataFrame

    try:
      #Если срабатывают условия, то данные отбрасываются
    
      if datafunc[i]['deactivated'] == "banned": #Если у человека статус забанен отбрасываем
        print("Сработало исключение - banned")
      
      if datafunc[i]['deactivated'] == "deleted": #Если у человека статус удален отбрасываем 
        print("Сработало исключение - deleted")

    except:  
    
      try: 
        if datafunc[i]['is_closed'] == True: #Если у человека закрыта страница отбрасываем
          print("Доступ к странице пользователя недоступен")
          print(last_name)
        else:
          framefunc = framefunc.append(new_row, ignore_index=True) 
          print(new_row)

      except:
        framefunc = framefunc.append(new_row, ignore_index=True)
        print(new_row)
    
    i += 1
  #frame1 = frame1.iloc[0:0]
  print(framefunc)
  return framefunc

# %%
response = requests.get("https://api.vk.com/method/friends.get", #Создаем запрос к API VK
                        params={ #Создаем словарь
                            "user_id": user_id, 
                            "order": "name", 
                            "count": 5000, 
                            "offset": 0,
                            "fields": "nickname", 

                            "access_token": token,
                            "v": version
                        }
                        )
data = response.json()
data

#изменение здесь
infoUser = {'main_id':[],'id_friend':[],'first_name':[],'last_name':[]}
#i = 0
frame1 = pd.DataFrame([infoUser])
frame1 = frame1.iloc[0:0]
data1 = data['response']['items']
count = data['response']['count']
frame1 = myfunction(data1, user_id, frame1)
# Out:
# {'main_id': 113001678, 'id_friend': 124652274, 'first_name': 'Alexander', 'last_name': 'Govorukhin'}
# Доступ к странице пользователя недоступен
# Pavlov
# {'main_id': 113001678, 'id_friend': 211137990, 'first_name': 'Anastasia', 'last_name': 'Fedorova'}
# Доступ к странице пользователя недоступен
# Mikhaylova
# {'main_id': 113001678, 'id_friend': 181948702, 'first_name': 'Andrey', 'last_name': 'Maslov'}
# Доступ к странице пользователя недоступен
# Levin
# {'main_id': 113001678, 'id_friend': 34008823, 'first_name': 'Arsen', 'last_name': 'Zinchenko'}
# {'main_id': 113001678, 'id_friend': 229491502, 'first_name': 'Artem', 'last_name': 'Kurnenkov'}
# {'main_id': 113001678, 'id_friend': 20794508, 'first_name': 'Artur', 'last_name': 'Makushev'}
# Доступ к странице пользователя недоступен
# Badyi
# Доступ к странице пользователя недоступен
# Danilin
# {'main_id': 113001678, 'id_friend': 39262511, 'first_name': 'Daniil', 'last_name': 'Paritsky'}
# {'main_id': 113001678, 'id_friend': 314194014, 'first_name': 'Danil', 'last_name': 'Emelyashin'}
# {'main_id': 113001678, 'id_friend': 149073861, 'first_name': 'Darya', 'last_name': 'Soshnikova'}
# {'main_id': 113001678, 'id_friend': 237842422, 'first_name': 'Dasha', 'last_name': 'Fedorova'}
# Доступ к странице пользователя недоступен
# Makeev
# {'main_id': 113001678, 'id_friend': 377465565, 'first_name': 'Dmitry', 'last_name': 'Arinushkin'}
# {'main_id': 113001678, 'id_friend': 612202967, 'first_name': 'Dmitry', 'last_name': 'Feoktistov'}
# {'main_id': 113001678, 'id_friend': 15360494, 'first_name': 'Dmitry', 'last_name': 'Ivanov'}
# {'main_id': 113001678, 'id_friend': 233210454, 'first_name': 'Dmitry', 'last_name': 'Menshikov'}
# {'main_id': 113001678, 'id_friend': 135182205, 'first_name': 'Doorbek', 'last_name': 'Salibaev'}
# Доступ к странице пользователя недоступен
# Mishin
# {'main_id': 113001678, 'id_friend': 143779216, 'first_name': 'Egor', 'last_name': 'Ruzaikin'}
# {'main_id': 113001678, 'id_friend': 21789079, 'first_name': 'Ekaterina', 'last_name': 'Matyash'}
# {'main_id': 113001678, 'id_friend': 239772243, 'first_name': 'Emil', 'last_name': 'Kyazimov'}
# {'main_id': 113001678, 'id_friend': 181254379, 'first_name': 'Evgeny', 'last_name': 'Urusov'}
# {'main_id': 113001678, 'id_friend': 209218232, 'first_name': 'Gamzat', 'last_name': 'Kusainov'}
# {'main_id': 113001678, 'id_friend': 180441581, 'first_name': 'Gato', 'last_name': 'Anonimus'}
# {'main_id': 113001678, 'id_friend': 131765293, 'first_name': 'Gennady', 'last_name': 'Skakodub'}
# Доступ к странице пользователя недоступен
# Papiashvili
# {'main_id': 113001678, 'id_friend': 116556411, 'first_name': 'Igor', 'last_name': 'Andryukov'}
# Доступ к странице пользователя недоступен
# Alcheev
# {'main_id': 113001678, 'id_friend': 218644757, 'first_name': 'Ilya', 'last_name': 'Larichev'}
# Доступ к странице пользователя недоступен
# Shakirov
# {'main_id': 113001678, 'id_friend': 18362790, 'first_name': 'Irina', 'last_name': 'Kuchina'}
# Доступ к странице пользователя недоступен
# Ivanova
# {'main_id': 113001678, 'id_friend': 144789718, 'first_name': 'Karina', 'last_name': 'Lyskova'}
# {'main_id': 113001678, 'id_friend': 147908271, 'first_name': 'Katerina', 'last_name': 'Belozyorskaya'}
# {'main_id': 113001678, 'id_friend': 189135415, 'first_name': 'Kirill', 'last_name': 'Anikin'}
# Доступ к странице пользователя недоступен
# Ostrova
# {'main_id': 113001678, 'id_friend': 87456493, 'first_name': 'Ksenia', 'last_name': 'Zalozhkina'}
# {'main_id': 113001678, 'id_friend': 226927713, 'first_name': 'Leonid', 'last_name': 'Lukashevich'}
# {'main_id': 113001678, 'id_friend': 182297238, 'first_name': 'Leonid', 'last_name': 'Zagorelsky'}
# {'main_id': 113001678, 'id_friend': 206111473, 'first_name': 'Maria', 'last_name': 'Mitina'}
# {'main_id': 113001678, 'id_friend': 99467665, 'first_name': 'Maria', 'last_name': 'Streltsova'}
# Доступ к странице пользователя недоступен
# Sizova
# {'main_id': 113001678, 'id_friend': 101278964, 'first_name': 'Masha', 'last_name': 'Makeeva'}
# {'main_id': 113001678, 'id_friend': 161594007, 'first_name': 'Maxim', 'last_name': 'Mikheev'}
# Доступ к странице пользователя недоступен
# Obleznev
# {'main_id': 113001678, 'id_friend': 175143412, 'first_name': 'Maxim', 'last_name': 'Russkikh'}
# {'main_id': 113001678, 'id_friend': 152087036, 'first_name': 'Maxim', 'last_name': 'Zuenko'}
# {'main_id': 113001678, 'id_friend': 280173352, 'first_name': 'Mikhail', 'last_name': 'Fursov'}
# Доступ к странице пользователя недоступен
# Borzov
# Доступ к странице пользователя недоступен
# Shilov
# {'main_id': 113001678, 'id_friend': 369829012, 'first_name': 'Oleg', 'last_name': 'Dementyev'}
# Доступ к странице пользователя недоступен
# Isaev
# Доступ к странице пользователя недоступен
# Mironov
# {'main_id': 113001678, 'id_friend': 37816448, 'first_name': 'Sanya', 'last_name': 'Sizov'}
# {'main_id': 113001678, 'id_friend': 621215806, 'first_name': 'Sergey', 'last_name': 'Ivanov'}
# Доступ к странице пользователя недоступен
# Komarova
# Доступ к странице пользователя недоступен
# Pevko
# {'main_id': 113001678, 'id_friend': 133224204, 'first_name': 'Taisia', 'last_name': 'Rudolf'}
# Доступ к странице пользователя недоступен
# Kuchina
# {'main_id': 113001678, 'id_friend': 163192338, 'first_name': 'Tolik', 'last_name': 'Tikhonov'}
# {'main_id': 113001678, 'id_friend': 73182682, 'first_name': 'Vadim', 'last_name': 'Nikitaev'}
# {'main_id': 113001678, 'id_friend': 54341868, 'first_name': 'Vadim', 'last_name': 'Stogov'}
# {'main_id': 113001678, 'id_friend': 163312070, 'first_name': 'Vasily', 'last_name': 'Ivanov'}
# {'main_id': 113001678, 'id_friend': 124480381, 'first_name': 'Vika', 'last_name': 'Vetrova'}
# Доступ к странице пользователя недоступен
# Pozdnyakova
# Доступ к странице пользователя недоступен
# Murov
# {'main_id': 113001678, 'id_friend': 70098839, 'first_name': 'Vladimir', 'last_name': 'Mullin'}
# {'main_id': 113001678, 'id_friend': 151553493, 'first_name': 'Yulia', 'last_name': 'Stogova'}
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - banned
#       main_id  id_friend first_name      last_name
# 0   113001678  124652274  Alexander     Govorukhin
# 1   113001678  211137990  Anastasia       Fedorova
# 2   113001678  181948702     Andrey         Maslov
# 3   113001678   34008823      Arsen      Zinchenko
# 4   113001678  229491502      Artem      Kurnenkov
# 5   113001678   20794508      Artur       Makushev
# 6   113001678   39262511     Daniil       Paritsky
# 7   113001678  314194014      Danil     Emelyashin
# 8   113001678  149073861      Darya     Soshnikova
# 9   113001678  237842422      Dasha       Fedorova
# 10  113001678  377465565     Dmitry     Arinushkin
# 11  113001678  612202967     Dmitry     Feoktistov
# 12  113001678   15360494     Dmitry         Ivanov
# 13  113001678  233210454     Dmitry      Menshikov
# 14  113001678  135182205    Doorbek       Salibaev
# 15  113001678  143779216       Egor       Ruzaikin
# 16  113001678   21789079  Ekaterina        Matyash
# 17  113001678  239772243       Emil       Kyazimov
# 18  113001678  181254379     Evgeny         Urusov
# 19  113001678  209218232     Gamzat       Kusainov
# 20  113001678  180441581       Gato       Anonimus
# 21  113001678  131765293    Gennady       Skakodub
# 22  113001678  116556411       Igor      Andryukov
# 23  113001678  218644757       Ilya       Larichev
# 24  113001678   18362790      Irina        Kuchina
# 25  113001678  144789718     Karina        Lyskova
# 26  113001678  147908271   Katerina  Belozyorskaya
# 27  113001678  189135415     Kirill         Anikin
# 28  113001678   87456493     Ksenia     Zalozhkina
# 29  113001678  226927713     Leonid    Lukashevich
# 30  113001678  182297238     Leonid     Zagorelsky
# 31  113001678  206111473      Maria         Mitina
# 32  113001678   99467665      Maria     Streltsova
# 33  113001678  101278964      Masha        Makeeva
# 34  113001678  161594007      Maxim        Mikheev
# 35  113001678  175143412      Maxim       Russkikh
# 36  113001678  152087036      Maxim         Zuenko
# 37  113001678  280173352    Mikhail         Fursov
# 38  113001678  369829012       Oleg      Dementyev
# 39  113001678   37816448      Sanya          Sizov
# 40  113001678  621215806     Sergey         Ivanov
# 41  113001678  133224204     Taisia         Rudolf
# 42  113001678  163192338      Tolik       Tikhonov
# 43  113001678   73182682      Vadim       Nikitaev
# 44  113001678   54341868      Vadim         Stogov
# 45  113001678  163312070     Vasily         Ivanov
# 46  113001678  124480381       Vika        Vetrova
# 47  113001678   70098839   Vladimir         Mullin
# 48  113001678  151553493      Yulia        Stogova

# %%
idFriendsUser = frame1['id_friend']
frame2 = copy.deepcopy(frame1) #Копируем DataFrame иначе данные у 1-го также будут изменяться 
i = 0
countOfidFriend = len(frame1['id_friend']) #Начинаем парсить друзей друзей
while i < countOfidFriend:
  response = requests.get("https://api.vk.com/method/friends.get",
                        params={
                            "user_id": idFriendsUser[i],
                            "order": "name",
                            "count": 5000,
                            "offset": 0,
                            "fields": "nickname",

                            "access_token": token,
                            "v": version
                        }
                        )
  if(response.json()):
    data2 = response.json()
    print(idFriendsUser[i])
    print(data2)
    data3 = data2['response']['items']
    count = data2['response']['count']
    frame2 = myfunction(data3, idFriendsUser[i], frame2)
    del data2
    i += 1

frame2
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# {'main_id': 87456493, 'id_friend': 132221966, 'first_name': 'Anastasia', 'last_name': 'Egorova'}
# {'main_id': 87456493, 'id_friend': 212447130, 'first_name': 'Anastasia', 'last_name': 'Kireeva'}
# {'main_id': 87456493, 'id_friend': 8931656, 'first_name': 'Anastasia', 'last_name': 'Korolyova'}
# {'main_id': 87456493, 'id_friend': 389736954, 'first_name': 'Anastasia', 'last_name': 'Larionova'}
# {'main_id': 87456493, 'id_friend': 27324030, 'first_name': 'Anastasia', 'last_name': 'Morozova'}
# {'main_id': 87456493, 'id_friend': 91556057, 'first_name': 'Anastasia', 'last_name': 'Morozova'}
# Доступ к странице пользователя недоступен
# Pankratova
# {'main_id': 87456493, 'id_friend': 90444583, 'first_name': 'Anastasia', 'last_name': 'Peys'}
# Доступ к странице пользователя недоступен
# Raenkova
# {'main_id': 87456493, 'id_friend': 414044946, 'first_name': 'Anastasia', 'last_name': 'Romanova'}
# {'main_id': 87456493, 'id_friend': 151601477, 'first_name': 'Anastasia', 'last_name': 'Sorokina'}
# {'main_id': 87456493, 'id_friend': 119506648, 'first_name': 'Anastasia', 'last_name': 'Vorozheykina'}
# {'main_id': 87456493, 'id_friend': 189107919, 'first_name': 'Andrey', 'last_name': 'Belashenko'}
# {'main_id': 87456493, 'id_friend': 211586349, 'first_name': 'Andrey', 'last_name': 'Chelovechkin'}
# {'main_id': 87456493, 'id_friend': 54139786, 'first_name': 'Andrey', 'last_name': 'Evstifeev'}
# {'main_id': 87456493, 'id_friend': 177092047, 'first_name': 'Andrey', 'last_name': 'Makhno'}
# {'main_id': 87456493, 'id_friend': 181948702, 'first_name': 'Andrey', 'last_name': 'Maslov'}
# {'main_id': 87456493, 'id_friend': 66686788, 'first_name': 'Angelina', 'last_name': 'Korzakova'}
# {'main_id': 87456493, 'id_friend': 929248, 'first_name': 'Anna', 'last_name': 'Andreeva'}
# {'main_id': 87456493, 'id_friend': 278064031, 'first_name': 'Anna', 'last_name': 'Beldanova'}
# {'main_id': 87456493, 'id_friend': 355957, 'first_name': 'Anna', 'last_name': 'Mayantseva'}
# Доступ к странице пользователя недоступен
# Shtogrina
# {'main_id': 87456493, 'id_friend': 122317232, 'first_name': 'Anna', 'last_name': 'Teslenko'}
# {'main_id': 87456493, 'id_friend': 1651207, 'first_name': 'Anton', 'last_name': 'Babak'}
# Доступ к странице пользователя недоступен
# Borov
# {'main_id': 87456493, 'id_friend': 217748032, 'first_name': 'Anton', 'last_name': 'Novikov'}
# {'main_id': 87456493, 'id_friend': 1388575, 'first_name': 'Anton', 'last_name': 'Serov'}
# {'main_id': 87456493, 'id_friend': 339720861, 'first_name': 'Anton', 'last_name': 'Voynov'}
# {'main_id': 87456493, 'id_friend': 60768765, 'first_name': 'Anya', 'last_name': 'Bogdanova'}
# {'main_id': 87456493, 'id_friend': 82377735, 'first_name': 'Anya', 'last_name': 'Mika'}
# {'main_id': 87456493, 'id_friend': 2263624, 'first_name': 'Anya', 'last_name': 'Shkandybina'}
# {'main_id': 87456493, 'id_friend': 471630108, 'first_name': 'Anyuta', 'last_name': 'Bogdanova'}
# Доступ к странице пользователя недоступен
# Balyabina
# {'main_id': 87456493, 'id_friend': 260953928, 'first_name': 'Arsen', 'last_name': 'Musailov'}
# {'main_id': 87456493, 'id_friend': 43565172, 'first_name': 'Artem', 'last_name': 'Arbuzov'}
# {'main_id': 87456493, 'id_friend': 229491502, 'first_name': 'Artem', 'last_name': 'Kurnenkov'}
# {'main_id': 87456493, 'id_friend': 567862992, 'first_name': 'Artem', 'last_name': 'Neizvestny'}
# {'main_id': 87456493, 'id_friend': 160337615, 'first_name': 'Artem', 'last_name': 'Novikov'}
# {'main_id': 87456493, 'id_friend': 249632577, 'first_name': 'Artem', 'last_name': 'Shimanov'}
# {'main_id': 87456493, 'id_friend': 161192714, 'first_name': 'Artyom', 'last_name': 'Zorin'}
# {'main_id': 87456493, 'id_friend': 190040725, 'first_name': 'Asya', 'last_name': 'Nametkina'}
# {'main_id': 87456493, 'id_friend': 19936429, 'first_name': 'Aygul', 'last_name': 'Batyrova'}
# Доступ к странице пользователя недоступен
# Badyi
# {'main_id': 87456493, 'id_friend': 155576281, 'first_name': 'Bayzak', 'last_name': 'Seytkhan'}
# Доступ к странице пользователя недоступен
# Imronov
# {'main_id': 87456493, 'id_friend': 253325689, 'first_name': 'Dadakhon', 'last_name': 'Sultanov'}
# {'main_id': 87456493, 'id_friend': 39262511, 'first_name': 'Daniil', 'last_name': 'Paritsky'}
# {'main_id': 87456493, 'id_friend': 124804258, 'first_name': 'Danya', 'last_name': 'Sargsyan'}
# {'main_id': 87456493, 'id_friend': 140638255, 'first_name': 'Daria', 'last_name': 'Kuznetsova'}
# {'main_id': 87456493, 'id_friend': 30426481, 'first_name': 'Darina', 'last_name': 'Zhete'}
# Доступ к странице пользователя недоступен
# Chernyakova
# {'main_id': 87456493, 'id_friend': 19532812, 'first_name': 'Darya', 'last_name': 'Kiseleva'}
# {'main_id': 87456493, 'id_friend': 105770084, 'first_name': 'Darya', 'last_name': 'Orlova'}
# {'main_id': 87456493, 'id_friend': 51864962, 'first_name': 'Darya', 'last_name': 'Peskova'}
# {'main_id': 87456493, 'id_friend': 237842422, 'first_name': 'Dasha', 'last_name': 'Fedorova'}
# {'main_id': 87456493, 'id_friend': 325459675, 'first_name': 'Dasha', 'last_name': 'Filatova'}
# {'main_id': 87456493, 'id_friend': 24593657, 'first_name': 'Dasha', 'last_name': 'Murochkina'}
# Доступ к странице пользователя недоступен
# Shvargina
# {'main_id': 87456493, 'id_friend': 58339967, 'first_name': 'Denis', 'last_name': 'Kuklyaev'}
# {'main_id': 87456493, 'id_friend': 232308727, 'first_name': 'Denis', 'last_name': 'Levikov'}
# Доступ к странице пользователя недоступен
# Senkov
# {'main_id': 87456493, 'id_friend': 42148311, 'first_name': 'Denni', 'last_name': 'Kut'}
# Доступ к странице пользователя недоступен
# Matisova
# {'main_id': 87456493, 'id_friend': 160977259, 'first_name': 'Dima', 'last_name': 'Chaykin'}
# {'main_id': 87456493, 'id_friend': 383616695, 'first_name': 'Dmitry', 'last_name': 'Degtyaryov'}
# {'main_id': 87456493, 'id_friend': 38041335, 'first_name': 'Dmitry', 'last_name': 'Khramenkov'}
# {'main_id': 87456493, 'id_friend': 40153749, 'first_name': 'Dmitry', 'last_name': 'Kibler'}
# {'main_id': 87456493, 'id_friend': 26202425, 'first_name': 'Dmitry', 'last_name': 'Vavrinyuk'}
# {'main_id': 87456493, 'id_friend': 71030431, 'first_name': 'Dmitry', 'last_name': 'Zaitov'}
# {'main_id': 87456493, 'id_friend': 374274742, 'first_name': 'Egor', 'last_name': 'Borozdin'}
# {'main_id': 87456493, 'id_friend': 96635, 'first_name': 'Egor', 'last_name': 'Grishin'}
# Доступ к странице пользователя недоступен
# Mishin
# {'main_id': 87456493, 'id_friend': 344356407, 'first_name': 'Egor', 'last_name': 'Nikolaychuk'}
# {'main_id': 87456493, 'id_friend': 198245847, 'first_name': 'Egor', 'last_name': 'Popov'}
# {'main_id': 87456493, 'id_friend': 139168002, 'first_name': 'Ekaterina', 'last_name': 'Averkieva'}
# Доступ к странице пользователя недоступен
# Levkevich
# Доступ к странице пользователя недоступен
# Sazonova
# Доступ к странице пользователя недоступен
# Selyakova
# {'main_id': 87456493, 'id_friend': 27373109, 'first_name': 'Ekaterina', 'last_name': 'Soldatova'}
# {'main_id': 87456493, 'id_friend': 14693991, 'first_name': 'Ekaterina', 'last_name': 'Solovyova'}
# Доступ к странице пользователя недоступен
# Alexandrovna
# {'main_id': 87456493, 'id_friend': 76084094, 'first_name': 'Elena', 'last_name': 'Belyaeva'}
# {'main_id': 87456493, 'id_friend': 2244605, 'first_name': 'Elena', 'last_name': 'Dmitruk'}
# {'main_id': 87456493, 'id_friend': 12632468, 'first_name': 'Elena', 'last_name': 'Shiryaeva (Grigoryeva)'}
# {'main_id': 87456493, 'id_friend': 192622012, 'first_name': 'Eleonora', 'last_name': 'Strelkova'}
# {'main_id': 87456493, 'id_friend': 94544256, 'first_name': 'Elizar', 'last_name': 'Gudmanov'}
# {'main_id': 87456493, 'id_friend': 151500926, 'first_name': 'Elizaveta', 'last_name': 'Malikova'}
# {'main_id': 87456493, 'id_friend': 2754191, 'first_name': 'Elizaveta', 'last_name': 'Okladnikova'}
# {'main_id': 87456493, 'id_friend': 27703715, 'first_name': 'Elizaveta', 'last_name': 'Pursiaynen'}
# {'main_id': 87456493, 'id_friend': 28349452, 'first_name': 'Elizaveta', 'last_name': 'Rebry'}
# {'main_id': 87456493, 'id_friend': 58856856, 'first_name': 'Evelina', 'last_name': 'Mikushkina'}
# {'main_id': 87456493, 'id_friend': 128993785, 'first_name': 'Evgenia', 'last_name': 'Filimonenko'}
# {'main_id': 87456493, 'id_friend': 152124629, 'first_name': 'Evgenia', 'last_name': 'Nikiforova'}
# {'main_id': 87456493, 'id_friend': 179899596, 'first_name': 'Evgeny', 'last_name': 'Manko'}
# Доступ к странице пользователя недоступен
# Pozharsky
# {'main_id': 87456493, 'id_friend': 412278403, 'first_name': 'Evgeny', 'last_name': 'Vakulenko'}
# {'main_id': 87456493, 'id_friend': 2758024, 'first_name': 'Eysi', 'last_name': 'Asy'}
# {'main_id': 87456493, 'id_friend': 414586053, 'first_name': 'Familia', 'last_name': 'Imya'}
# {'main_id': 87456493, 'id_friend': 12898105, 'first_name': 'Galina', 'last_name': 'Gavrilova'}
# {'main_id': 87456493, 'id_friend': 209218232, 'first_name': 'Gamzat', 'last_name': 'Kusainov'}
# {'main_id': 87456493, 'id_friend': 87822545, 'first_name': 'Georgy', 'last_name': 'Lopatin'}
# Доступ к странице пользователя недоступен
# Ponomarev
# Доступ к странице пользователя недоступен
# Sorokin
# {'main_id': 87456493, 'id_friend': 2958620, 'first_name': 'Ilya', 'last_name': 'Kapranov'}
# {'main_id': 87456493, 'id_friend': 120797223, 'first_name': 'Ilya', 'last_name': 'Tumanov'}
# Доступ к странице пользователя недоступен
# Son
# {'main_id': 87456493, 'id_friend': 38483631, 'first_name': 'Inna', 'last_name': 'Mednik'}
# {'main_id': 87456493, 'id_friend': 186147314, 'first_name': 'Inna', 'last_name': 'Yanskaya'}
# {'main_id': 87456493, 'id_friend': 238558036, 'first_name': 'Ioanna', 'last_name': 'Funtusova'}
# {'main_id': 87456493, 'id_friend': 142990262, 'first_name': 'Irina', 'last_name': 'Drobitko'}
# {'main_id': 87456493, 'id_friend': 2818887, 'first_name': 'Irina', 'last_name': 'Murchikova'}
# {'main_id': 87456493, 'id_friend': 38737306, 'first_name': 'Ivan', 'last_name': 'Kuimov'}
# {'main_id': 87456493, 'id_friend': 35522980, 'first_name': 'Ivan', 'last_name': 'Sokolov'}
# {'main_id': 87456493, 'id_friend': 388003541, 'first_name': 'Joel Vianny', 'last_name': 'Mpegna'}
# {'main_id': 87456493, 'id_friend': 73539979, 'first_name': 'Karai', 'last_name': 'Polukrovka'}
# {'main_id': 87456493, 'id_friend': 82539574, 'first_name': 'Karolina', 'last_name': 'Logvinova'}
# Доступ к странице пользователя недоступен
# Trotskaya
# {'main_id': 87456493, 'id_friend': 282772084, 'first_name': 'Khogart', 'last_name': 'Li'}
# {'main_id': 87456493, 'id_friend': 333435295, 'first_name': 'Kira', 'last_name': 'Zolotova'}
# {'main_id': 87456493, 'id_friend': 189135415, 'first_name': 'Kirill', 'last_name': 'Anikin'}
# Доступ к странице пользователя недоступен
# Lakhinov
# {'main_id': 87456493, 'id_friend': 421874816, 'first_name': 'Kirill', 'last_name': 'Shapovalov'}
# {'main_id': 87456493, 'id_friend': 255131364, 'first_name': 'Kirill', 'last_name': 'Suvorov'}
# {'main_id': 87456493, 'id_friend': 93047688, 'first_name': 'Kirill', 'last_name': 'Troyan'}
# {'main_id': 87456493, 'id_friend': 235598630, 'first_name': 'Kirill', 'last_name': 'Tuzhenkov'}
# {'main_id': 87456493, 'id_friend': 228869386, 'first_name': 'Kirill', 'last_name': 'Zhelnov'}
# {'main_id': 87456493, 'id_friend': 215598500, 'first_name': 'Kristina', 'last_name': 'Ermakova'}
# Доступ к странице пользователя недоступен
# Ostrova
# {'main_id': 87456493, 'id_friend': 32580005, 'first_name': 'Ksenia', 'last_name': 'Gutsol'}
# {'main_id': 87456493, 'id_friend': 36227301, 'first_name': 'Ksenia', 'last_name': 'Kudinova'}
# Доступ к странице пользователя недоступен
# Mikhalchenko
# {'main_id': 87456493, 'id_friend': 138159700, 'first_name': 'Ksenia', 'last_name': 'Prokudina'}
# {'main_id': 87456493, 'id_friend': 201883037, 'first_name': 'Kurban', 'last_name': 'Khalibekov'}
# {'main_id': 87456493, 'id_friend': 533143446, 'first_name': 'Leo', 'last_name': 'Vitkovskii'}
# {'main_id': 87456493, 'id_friend': 182297238, 'first_name': 'Leonid', 'last_name': 'Zagorelsky'}
# {'main_id': 87456493, 'id_friend': 325769182, 'first_name': 'Leonidasiusik', 'last_name': 'Galyutiunus'}
# {'main_id': 87456493, 'id_friend': 159193486, 'first_name': 'Lev', 'last_name': 'Dementyev'}
# Доступ к странице пользователя недоступен
# Dzhumabekova
# {'main_id': 87456493, 'id_friend': 50344793, 'first_name': 'Liza', 'last_name': 'Teterina'}
# {'main_id': 87456493, 'id_friend': 398134642, 'first_name': 'Lutfullo', 'last_name': 'Sharipov'}
# {'main_id': 87456493, 'id_friend': 78849992, 'first_name': 'Lyubochka', 'last_name': 'Fodola'}
# {'main_id': 87456493, 'id_friend': 503623987, 'first_name': 'Mahamadou', 'last_name': 'Samake'}
# {'main_id': 87456493, 'id_friend': 30067410, 'first_name': 'Maria', 'last_name': 'Balitskaya'}
# {'main_id': 87456493, 'id_friend': 480685371, 'first_name': 'Maria', 'last_name': 'Bogdanova'}
# {'main_id': 87456493, 'id_friend': 238725911, 'first_name': 'Maria', 'last_name': 'Fedulova'}
# {'main_id': 87456493, 'id_friend': 7954370, 'first_name': 'Maria', 'last_name': 'Filyuchkova'}
# {'main_id': 87456493, 'id_friend': 29478543, 'first_name': 'Maria', 'last_name': 'Gryaznevich'}
# {'main_id': 87456493, 'id_friend': 69608876, 'first_name': 'Maria', 'last_name': 'Kiseleva'}
# Доступ к странице пользователя недоступен
# Nezherenko
# {'main_id': 87456493, 'id_friend': 73083516, 'first_name': 'Maria', 'last_name': 'Nikitaeva'}
# {'main_id': 87456493, 'id_friend': 335620894, 'first_name': 'Maria', 'last_name': 'Pudan'}
# {'main_id': 87456493, 'id_friend': 38866175, 'first_name': 'Maria', 'last_name': 'Samoylenko'}
# {'main_id': 87456493, 'id_friend': 236068012, 'first_name': 'Marietta', 'last_name': 'Koval'}
# {'main_id': 87456493, 'id_friend': 118004471, 'first_name': 'Marina', 'last_name': 'Aryuzina'}
# {'main_id': 87456493, 'id_friend': 346078354, 'first_name': 'Masha', 'last_name': 'Gorelova'}
# Доступ к странице пользователя недоступен
# Vorobyeva
# Доступ к странице пользователя недоступен
# Burov
# {'main_id': 87456493, 'id_friend': 394368562, 'first_name': 'Max', 'last_name': 'Fray'}
# {'main_id': 87456493, 'id_friend': 61517541, 'first_name': 'Max', 'last_name': 'Gorachev'}
# {'main_id': 87456493, 'id_friend': 318150082, 'first_name': 'Max', 'last_name': 'Mashtakov'}
# {'main_id': 87456493, 'id_friend': 202645268, 'first_name': 'Maxim', 'last_name': 'Arefyev'}
# {'main_id': 87456493, 'id_friend': 113001678, 'first_name': 'Maxim', 'last_name': 'Margolin'}
# {'main_id': 87456493, 'id_friend': 161594007, 'first_name': 'Maxim', 'last_name': 'Mikheev'}
# {'main_id': 87456493, 'id_friend': 137070361, 'first_name': 'Maxim', 'last_name': 'Rogozha'}
# {'main_id': 87456493, 'id_friend': 293403171, 'first_name': 'Mayya', 'last_name': 'Schemelyova'}
# {'main_id': 87456493, 'id_friend': 291712387, 'first_name': 'Melania', 'last_name': 'Frolova'}
# {'main_id': 87456493, 'id_friend': 267836703, 'first_name': 'Milana', 'last_name': 'Shereuzheva'}
# {'main_id': 87456493, 'id_friend': 169955936, 'first_name': 'Milena', 'last_name': 'Baryshnikova'}
# {'main_id': 87456493, 'id_friend': 153783525, 'first_name': 'Milena', 'last_name': 'Shalamay'}
# Доступ к странице пользователя недоступен
# Gorchakov
# {'main_id': 87456493, 'id_friend': 151121744, 'first_name': 'Misha', 'last_name': 'Kazakov'}
# {'main_id': 87456493, 'id_friend': 22199973, 'first_name': 'Mitya', 'last_name': 'Fokin'}
# Доступ к странице пользователя недоступен
# Stepanova
# {'main_id': 87456493, 'id_friend': 186330011, 'first_name': 'Murad', 'last_name': 'Usmanov'}
# Доступ к странице пользователя недоступен
# Lopakhtina
# {'main_id': 87456493, 'id_friend': 604757251, 'first_name': 'Nadezhda', 'last_name': 'Petrova'}
# {'main_id': 87456493, 'id_friend': 164381837, 'first_name': 'Nadezhda', 'last_name': 'Petrova'}
# {'main_id': 87456493, 'id_friend': 11883307, 'first_name': 'Nastya', 'last_name': 'Shakhbazova'}
# {'main_id': 87456493, 'id_friend': 30608335, 'first_name': 'Natalia', 'last_name': 'Breeva'}
# {'main_id': 87456493, 'id_friend': 11545412, 'first_name': 'Natalya', 'last_name': 'Bondarik'}
# Доступ к странице пользователя недоступен
# Andreev
# {'main_id': 87456493, 'id_friend': 71974864, 'first_name': 'Nikita', 'last_name': 'Basarev'}
# Доступ к странице пользователя недоступен
# Kapitunov
# {'main_id': 87456493, 'id_friend': 195486671, 'first_name': 'Nikita', 'last_name': 'Sidorov'}
# {'main_id': 87456493, 'id_friend': 295257757, 'first_name': 'Nikita', 'last_name': 'Stromtsov'}
# {'main_id': 87456493, 'id_friend': 124775822, 'first_name': 'Nikita', 'last_name': 'Sukhanov'}
# {'main_id': 87456493, 'id_friend': 237146928, 'first_name': 'Nikita', 'last_name': 'Timofeev'}
# {'main_id': 87456493, 'id_friend': 437124031, 'first_name': 'Oleg', 'last_name': 'Bezzubkin'}
# Доступ к странице пользователя недоступен
# Kamby
# {'main_id': 87456493, 'id_friend': 669707, 'first_name': 'Olga', 'last_name': 'Orchinskaya'}
# Доступ к странице пользователя недоступен
# Verpakhovskaya
# {'main_id': 87456493, 'id_friend': 25744607, 'first_name': 'Olya', 'last_name': 'Fateeva'}
# {'main_id': 87456493, 'id_friend': 172003102, 'first_name': 'Olya', 'last_name': 'Filatova'}
# Доступ к странице пользователя недоступен
# Astashin
# {'main_id': 87456493, 'id_friend': 607132876, 'first_name': 'Petr', 'last_name': 'Romanov'}
# {'main_id': 87456493, 'id_friend': 138620450, 'first_name': 'Polina', 'last_name': 'Demicheva'}
# {'main_id': 87456493, 'id_friend': 315471300, 'first_name': 'Polina', 'last_name': 'Frolova'}
# {'main_id': 87456493, 'id_friend': 151615575, 'first_name': 'Polina', 'last_name': 'Shabanova'}
# {'main_id': 87456493, 'id_friend': 460823663, 'first_name': 'Radmir', 'last_name': 'Khaniev'}
# Доступ к странице пользователя недоступен
# Isaev
# {'main_id': 87456493, 'id_friend': 596452221, 'first_name': 'Robert', 'last_name': 'Kortiev'}
# {'main_id': 87456493, 'id_friend': 194301690, 'first_name': 'Roma', 'last_name': 'Tochilkin'}
# Доступ к странице пользователя недоступен
# Balandin
# {'main_id': 87456493, 'id_friend': 370586073, 'first_name': 'Roman', 'last_name': 'Filchenkov'}
# Доступ к странице пользователя недоступен
# Klimenkov
# Доступ к странице пользователя недоступен
# Kochekaev
# {'main_id': 87456493, 'id_friend': 158452146, 'first_name': 'Roman', 'last_name': 'Kovalyov'}
# {'main_id': 87456493, 'id_friend': 281641201, 'first_name': 'Roman', 'last_name': 'Simanovsky'}
# {'main_id': 87456493, 'id_friend': 282399323, 'first_name': 'Rostislav', 'last_name': 'Churbanov'}
# Доступ к странице пользователя недоступен
# Al
# {'main_id': 87456493, 'id_friend': 328450009, 'first_name': 'Sakoi', 'last_name': 'Sumire'}
# {'main_id': 87456493, 'id_friend': 314857698, 'first_name': 'Salavat', 'last_name': 'Gabdushov'}
# {'main_id': 87456493, 'id_friend': 63991174, 'first_name': 'Salim', 'last_name': 'Gilamov'}
# {'main_id': 87456493, 'id_friend': 164830053, 'first_name': 'Sanya', 'last_name': 'Vilik'}
# {'main_id': 87456493, 'id_friend': 298805068, 'first_name': 'Sayidmagomed', 'last_name': 'Alyasaev'}
# {'main_id': 87456493, 'id_friend': 22769317, 'first_name': 'Serafim', 'last_name': 'Stepanov'}
# Доступ к странице пользователя недоступен
# Balandin
# {'main_id': 87456493, 'id_friend': 158991623, 'first_name': 'Sergey', 'last_name': 'Dmitrenko'}
# Доступ к странице пользователя недоступен
# Dudko
# Доступ к странице пользователя недоступен
# Kazantsev
# {'main_id': 87456493, 'id_friend': 7689330, 'first_name': 'Sergey', 'last_name': 'Klochkov'}
# {'main_id': 87456493, 'id_friend': 156924120, 'first_name': 'Sergey', 'last_name': 'Kulikov'}
# {'main_id': 87456493, 'id_friend': 179354408, 'first_name': 'Sergey', 'last_name': 'Shutov'}
# {'main_id': 87456493, 'id_friend': 1178282, 'first_name': 'Sergey', 'last_name': 'Yakimov'}
# {'main_id': 87456493, 'id_friend': 197448365, 'first_name': 'Sharaf', 'last_name': 'Zikrakov'}
# {'main_id': 87456493, 'id_friend': 566556676, 'first_name': 'Shokhrat', 'last_name': 'Esenov'}
# {'main_id': 87456493, 'id_friend': 411340336, 'first_name': 'Shukhrat', 'last_name': 'Rakhmatov'}
# Доступ к странице пользователя недоступен
# Malafeev
# Доступ к странице пользователя недоступен
# Li
# {'main_id': 87456493, 'id_friend': 81768658, 'first_name': 'Sonya', 'last_name': 'Schedrova'}
# {'main_id': 87456493, 'id_friend': 137589223, 'first_name': 'Stepan', 'last_name': 'Belogay'}
# Доступ к странице пользователя недоступен
# Ushakova
# {'main_id': 87456493, 'id_friend': 118958141, 'first_name': 'Sveta', 'last_name': 'Fyodorova'}
# Доступ к странице пользователя недоступен
# Liina
# {'main_id': 87456493, 'id_friend': 27269700, 'first_name': 'Svetlana', 'last_name': 'Rubanik'}
# {'main_id': 87456493, 'id_friend': 249926489, 'first_name': 'Taisia', 'last_name': 'Popova'}
# Доступ к странице пользователя недоступен
# Dmitrieva
# {'main_id': 87456493, 'id_friend': 162002614, 'first_name': 'Tatyana', 'last_name': 'Epaneshnikova'}
# {'main_id': 87456493, 'id_friend': 163734942, 'first_name': 'Tatyana', 'last_name': 'Laryutina'}
# {'main_id': 87456493, 'id_friend': 172184332, 'first_name': 'Taya', 'last_name': 'Btemirova'}
# {'main_id': 87456493, 'id_friend': 182923177, 'first_name': 'Taya', 'last_name': 'Pakhomova'}
# Доступ к странице пользователя недоступен
# Reztsov
# {'main_id': 87456493, 'id_friend': 550794672, 'first_name': 'Timur', 'last_name': 'Kuznetsov'}
# {'main_id': 87456493, 'id_friend': 292022627, 'first_name': 'Timur', 'last_name': 'Muxinov'}
# Доступ к странице пользователя недоступен
# Sultanov
# {'main_id': 87456493, 'id_friend': 268982405, 'first_name': 'Vadim', 'last_name': 'Kislyachenko'}
# {'main_id': 87456493, 'id_friend': 73182682, 'first_name': 'Vadim', 'last_name': 'Nikitaev'}
# {'main_id': 87456493, 'id_friend': 13407190, 'first_name': 'Vadim', 'last_name': 'Novikov'}
# {'main_id': 87456493, 'id_friend': 4548158, 'first_name': 'Valentina', 'last_name': 'Baryabina'}
# {'main_id': 87456493, 'id_friend': 191827686, 'first_name': 'Valentinka', 'last_name': 'Kataeva'}
# {'main_id': 87456493, 'id_friend': 42332387, 'first_name': 'Valera', 'last_name': 'Dubrovin'}
# Доступ к странице пользователя недоступен
# Orlova
# {'main_id': 87456493, 'id_friend': 12029713, 'first_name': 'Vanya', 'last_name': 'Mazin'}
# {'main_id': 87456493, 'id_friend': 308336478, 'first_name': 'Varvara', 'last_name': 'Yagudina'}
# {'main_id': 87456493, 'id_friend': 101048233, 'first_name': 'Veleslava', 'last_name': 'Mokhova'}
# {'main_id': 87456493, 'id_friend': 119235166, 'first_name': 'Vera', 'last_name': 'Grigoryeva'}
# {'main_id': 87456493, 'id_friend': 94870935, 'first_name': 'Veronika', 'last_name': 'Simpirovich'}
# {'main_id': 87456493, 'id_friend': 192091505, 'first_name': 'Veronika', 'last_name': 'Zhukova'}
# {'main_id': 87456493, 'id_friend': 337540258, 'first_name': 'Vevo', 'last_name': 'Sayan'}
# {'main_id': 87456493, 'id_friend': 243605669, 'first_name': 'Viktoria', 'last_name': 'Brueva'}
# {'main_id': 87456493, 'id_friend': 248317759, 'first_name': 'Viktoria', 'last_name': 'Kuzovina'}
# {'main_id': 87456493, 'id_friend': 44041645, 'first_name': 'Viktoria', 'last_name': 'Pomfa'}
# {'main_id': 87456493, 'id_friend': 213090701, 'first_name': 'Viktoria', 'last_name': 'Shkatova'}
# {'main_id': 87456493, 'id_friend': 421979658, 'first_name': 'Vitali', 'last_name': 'Sur'}
# Доступ к странице пользователя недоступен
# Dementyev
# {'main_id': 87456493, 'id_friend': 145399792, 'first_name': 'Vlad', 'last_name': 'Nikiforov'}
# Доступ к странице пользователя недоступен
# Peresvet
# Доступ к странице пользователя недоступен
# Brysina
# Доступ к странице пользователя недоступен
# Arsenyev
# {'main_id': 87456493, 'id_friend': 238738554, 'first_name': 'Vladimir', 'last_name': 'Fomenko'}
# {'main_id': 87456493, 'id_friend': 194225041, 'first_name': 'Vladimir', 'last_name': 'Guschin'}
# Доступ к странице пользователя недоступен
# Mamontov
# {'main_id': 87456493, 'id_friend': 70098839, 'first_name': 'Vladimir', 'last_name': 'Mullin'}
# {'main_id': 87456493, 'id_friend': 229536920, 'first_name': 'Vladislav', 'last_name': 'Cheglakov'}
# Доступ к странице пользователя недоступен
# Gizatulin
# {'main_id': 87456493, 'id_friend': 187924153, 'first_name': 'Yana', 'last_name': 'Zhuravlyova'}
# Доступ к странице пользователя недоступен
# Karpova
# {'main_id': 87456493, 'id_friend': 186261254, 'first_name': 'Yuliana', 'last_name': 'Davydova'}
# Доступ к странице пользователя недоступен
# Starodubov
# {'main_id': 87456493, 'id_friend': 146568158, 'first_name': 'Zhenya', 'last_name': 'Morozov'}
# {'main_id': 87456493, 'id_friend': 918955, 'first_name': 'Zhu', 'last_name': 'Tyan'}
# {'main_id': 87456493, 'id_friend': 94010699, 'first_name': 'Zina', 'last_name': 'Zinochka'}
# {'main_id': 87456493, 'id_friend': 178135689, 'first_name': 'Zoya', 'last_name': 'Abrosimova'}
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
#         main_id  id_friend first_name   last_name
# 0     113001678  124652274  Alexander  Govorukhin
# 1     113001678  211137990  Anastasia    Fedorova
# 2     113001678  181948702     Andrey      Maslov
# 3     113001678   34008823      Arsen   Zinchenko
# 4     113001678  229491502      Artem   Kurnenkov
# ...         ...        ...        ...         ...
# 4266   87456493  186261254    Yuliana    Davydova
# 4267   87456493  146568158     Zhenya     Morozov
# 4268   87456493     918955        Zhu        Tyan
# 4269   87456493   94010699       Zina    Zinochka
# 4270   87456493  178135689       Zoya  Abrosimova
#
# [4271 rows x 4 columns]
# 226927713
# {'response': {'count': 138, 'items': [{'id': 124652274, 'nickname': '', 'track_code': 'cd7e8893xABh5QCqiTWQXvH-e6BVjJ3NrP_nRuW6F0n_e8R_ntWpaz7cOKyIOJ9SwwT3Cu_n7tm18_AogclI', 'first_name': 'Alexander', 'last_name': 'Govorukhin', 'can_access_closed': True, 'is_closed': False}, {'id': 585125020, 'nickname': '', 'track_code': '12e3facfSF5dXe-TRJVB3QY_t8psEArJ3c2_F2pIp6yYtxO_PMclNVRrhJ9ElUHfMsc-ZNZ7ed3Ewah5Djv4', 'first_name': 'Alexander', 'last_name': 'Romanov', 'can_access_closed': True, 'is_closed': False}, {'id': 134696362, 'nickname': '', 'track_code': '932493cfuIODsLY81cKiodKxc58hRjPw-ovei7bFdCkk2NmuUGXV6NuF3mzUxvf55kr-M5stQOTjh8nl0rYr', 'first_name': 'Alexander', 'last_name': 'Zakonov', 'can_access_closed': True, 'is_closed': False}, {'id': 387462451, 'nickname': '', 'track_code': 'f0a972435lPN9k9_b6cPXd-x9wqWzVYtf8F__M7LwQNI_yO0VT6LOJWSd3wzoAxe7k15pSymJTlmzWiSqrie', 'first_name': 'Alexandr', 'last_name': 'Goryachev', 'can_access_closed': True, 'is_closed': False}, {'id': 335455686, 'nickname': '', 'track_code': '46812a311trKTWjyu4qw4xrHQ2v4iuhNhWH9j7J50DAqrJFPtJa7sZUsV_i4i7TuKznAw0Lhm1mcberh1gqP', 'first_name': 'Alexandra', 'last_name': 'Klinshova', 'can_access_closed': True, 'is_closed': False}, {'id': 389264061, 'nickname': '', 'track_code': '56f614fc1q3WqC5xp9rqYkGF7h3c90Xw71ovbqLnDvkJ_N_Dou-7xo7OQSP61-FmcH1jsmacNuT2VjgAxpRR', 'first_name': 'Alexandra', 'last_name': 'Lukashevich', 'can_access_closed': True, 'is_closed': False}, {'id': 417613125, 'nickname': '', 'track_code': '39e1e99brPpESSxjAr_yBIDbxyeYrmQoWpv4ex9qF7l9Hqo9vpXBkRx7RzMFsfAAtSJOjCLFFzxDl-8VexlI', 'first_name': 'Alexandra', 'last_name': 'Sergeeva', 'can_access_closed': True, 'is_closed': False}, {'id': 133604759, 'nickname': 'Sergeevich', 'track_code': '253216d3Hp4mtwCdSuMFAgpUexLr5Kj6X7GVsQ5Bo4-s12DTOhJz9X_SbZ9K5VADOav1tVGP2-5GvYLfajL8', 'first_name': 'Alexey', 'last_name': 'Poluvalov', 'can_access_closed': True, 'is_closed': False}, {'id': 99138057, 'nickname': '', 'track_code': '8a558c84KThtVcceYATi3qc3c5BofqOgyhp85Z8_yboUDXK5Eh5EUz8w-RJqBePSn8r_CLkZw63dARmL-0w', 'first_name': 'Alexey', 'last_name': 'Rusakov', 'can_access_closed': True, 'is_closed': False}, {'id': 101809085, 'nickname': '', 'track_code': '7fab458fpMUvp0iwPvgI68sjGe0JpdJFR36eawR-MS6fYfuqh87JrnSQcbVt_AG4-9uaRrPOoVFecokFYA1u', 'first_name': 'Alina', 'last_name': 'Parafieva', 'can_access_closed': True, 'is_closed': False}, {'id': 571714923, 'nickname': '', 'track_code': 'd664eb1c4BAnCSC4vHBzakFcNdXQ2c9k-PbLCnbX8SjSIO2C4sKNe3g-SLi-c31of628eGqyvHDh-txkEqSu', 'first_name': 'Alya', 'last_name': 'Syrkina', 'can_access_closed': True, 'is_closed': False}, {'id': 211495056, 'nickname': '', 'track_code': 'abab356eBxSZ16R3c9E_pDvjCXT6wYvB770dV95UDEJLpPA1eP9qf8TulSB21WqpBRuH3ECq-NX2sQo5uidT', 'first_name': 'Anastasia', 'last_name': 'Kotova', 'can_access_closed': False, 'is_closed': True}, {'id': 248251523, 'nickname': '', 'track_code': '9d29c9b6qefGnMLa1-glgd4R12MkB7pLPXYwrFuKYTzO1vZzsjLEjJ75qozS4nHW4-xezp5syV8keifCP_k-', 'first_name': 'Anastasia', 'last_name': 'Oboyanskaya', 'can_access_closed': True, 'is_closed': False}, {'id': 233445930, 'nickname': '', 'track_code': '87fa17b3S3BTbWwimWgNdSy00pd6bAbcOTdXI0GbbEU48joOceEmGwFZBCGdPV11FEVaOcAHdcggO0BNJegz', 'first_name': 'Anastasia', 'last_name': 'Zakharova', 'can_access_closed': True, 'is_closed': False}, {'id': 157147598, 'nickname': '', 'track_code': 'e9851971usySZisrDaXRbyNFBLpoSBvVMd9r5JB3TKdK3CAmJRXXp8sCE3kBpIJrGriGHNIjaMEo03yK9AQT', 'first_name': 'Andrey', 'last_name': 'Frantsev', 'can_access_closed': True, 'is_closed': False}, {'id': 101923962, 'nickname': '', 'track_code': '7d2ca8f6L9lIk9Rx3q7ot-Pk7C9cS_q19s3guw8jnElcJ4ysGlVCshug63Xd_ua93xVhg-YgiaHvwffVa1DD', 'first_name': 'Andrey', 'last_name': 'Kutuzov', 'can_access_closed': True, 'is_closed': False}, {'id': 68263714, 'nickname': '', 'track_code': '3dbf3604SKwlZqeDswEVPhhmsJWqnr0-POQhK11uh0mvtZdgamAlxyhTy4C5UhI5P58_DXv53TMr_0RFOR0', 'first_name': 'Andrey', 'last_name': 'Vinogradov', 'can_acce ...
# {'main_id': 226927713, 'id_friend': 124652274, 'first_name': 'Alexander', 'last_name': 'Govorukhin'}
# {'main_id': 226927713, 'id_friend': 585125020, 'first_name': 'Alexander', 'last_name': 'Romanov'}
# {'main_id': 226927713, 'id_friend': 134696362, 'first_name': 'Alexander', 'last_name': 'Zakonov'}
# {'main_id': 226927713, 'id_friend': 387462451, 'first_name': 'Alexandr', 'last_name': 'Goryachev'}
# {'main_id': 226927713, 'id_friend': 335455686, 'first_name': 'Alexandra', 'last_name': 'Klinshova'}
# {'main_id': 226927713, 'id_friend': 389264061, 'first_name': 'Alexandra', 'last_name': 'Lukashevich'}
# {'main_id': 226927713, 'id_friend': 417613125, 'first_name': 'Alexandra', 'last_name': 'Sergeeva'}
# {'main_id': 226927713, 'id_friend': 133604759, 'first_name': 'Alexey', 'last_name': 'Poluvalov'}
# {'main_id': 226927713, 'id_friend': 99138057, 'first_name': 'Alexey', 'last_name': 'Rusakov'}
# {'main_id': 226927713, 'id_friend': 101809085, 'first_name': 'Alina', 'last_name': 'Parafieva'}
# {'main_id': 226927713, 'id_friend': 571714923, 'first_name': 'Alya', 'last_name': 'Syrkina'}
# Доступ к странице пользователя недоступен
# Kotova
# {'main_id': 226927713, 'id_friend': 248251523, 'first_name': 'Anastasia', 'last_name': 'Oboyanskaya'}
# {'main_id': 226927713, 'id_friend': 233445930, 'first_name': 'Anastasia', 'last_name': 'Zakharova'}
# {'main_id': 226927713, 'id_friend': 157147598, 'first_name': 'Andrey', 'last_name': 'Frantsev'}
# {'main_id': 226927713, 'id_friend': 101923962, 'first_name': 'Andrey', 'last_name': 'Kutuzov'}
# {'main_id': 226927713, 'id_friend': 68263714, 'first_name': 'Andrey', 'last_name': 'Vinogradov'}
# {'main_id': 226927713, 'id_friend': 429927773, 'first_name': 'Animatsia', 'last_name': 'Otelya-Rivyera'}
# {'main_id': 226927713, 'id_friend': 505000860, 'first_name': 'Anna', 'last_name': 'Dolgova'}
# {'main_id': 226927713, 'id_friend': 177268418, 'first_name': 'Anna', 'last_name': 'Feschenko'}
# {'main_id': 226927713, 'id_friend': 297638575, 'first_name': 'Annie', 'last_name': 'Sunshine'}
# {'main_id': 226927713, 'id_friend': 467365126, 'first_name': 'Anton', 'last_name': 'Efremov'}
# {'main_id': 226927713, 'id_friend': 142524045, 'first_name': 'Anton', 'last_name': 'Ilyin'}
# {'main_id': 226927713, 'id_friend': 132011950, 'first_name': 'Anton', 'last_name': 'Makhov'}
# {'main_id': 226927713, 'id_friend': 576872798, 'first_name': 'Arseny', 'last_name': 'Romanov'}
# Доступ к странице пользователя недоступен
# Vavin
# {'main_id': 226927713, 'id_friend': 341447060, 'first_name': 'Artem', 'last_name': 'Kiskov'}
# Доступ к странице пользователя недоступен
# Kuznetsov
# {'main_id': 226927713, 'id_friend': 155576281, 'first_name': 'Bayzak', 'last_name': 'Seytkhan'}
# {'main_id': 226927713, 'id_friend': 228010446, 'first_name': 'Daniil', 'last_name': 'Savinovsky'}
# Доступ к странице пользователя недоступен
# Lisova
# {'main_id': 226927713, 'id_friend': 92547169, 'first_name': 'Dasha', 'last_name': 'Bureshkina'}
# {'main_id': 226927713, 'id_friend': 291403997, 'first_name': 'Diana', 'last_name': 'Karandeeva'}
# {'main_id': 226927713, 'id_friend': 334725992, 'first_name': 'Dima', 'last_name': 'Papshev'}
# {'main_id': 226927713, 'id_friend': 377465565, 'first_name': 'Dmitry', 'last_name': 'Arinushkin'}
# Доступ к странице пользователя недоступен
# Lozhnov
# {'main_id': 226927713, 'id_friend': 156896745, 'first_name': 'Dmitry', 'last_name': 'Podolsky'}
# {'main_id': 226927713, 'id_friend': 195023970, 'first_name': 'Dmitry', 'last_name': 'Sinitsyn'}
# {'main_id': 226927713, 'id_friend': 175759148, 'first_name': 'Egor', 'last_name': 'Dokuchaev'}
# {'main_id': 226927713, 'id_friend': 547740774, 'first_name': 'Egor', 'last_name': 'Fedorov'}
# Доступ к странице пользователя недоступен
# Fyodorov
# {'main_id': 226927713, 'id_friend': 679801079, 'first_name': 'Egor', 'last_name': 'Fyodorov'}
# Доступ к странице пользователя недоступен
# Fyodorov
# Доступ к странице пользователя недоступен
# Fyodorov
# {'main_id': 226927713, 'id_friend': 95544226, 'first_name': 'Egor', 'last_name': 'Yuryevich'}
# {'main_id': 226927713, 'id_friend': 256831026, 'first_name': 'Elena', 'last_name': 'Kazantseva'}
# {'main_id': 226927713, 'id_friend': 254252465, 'first_name': 'Elizaveta', 'last_name': 'Monchakovskaya'}
# {'main_id': 226927713, 'id_friend': 516250285, 'first_name': 'Elizaveta', 'last_name': 'Romanevskaya'}
# {'main_id': 226927713, 'id_friend': 431883385, 'first_name': 'Eva', 'last_name': 'Larionova'}
# {'main_id': 226927713, 'id_friend': 161114875, 'first_name': 'Evgeny', 'last_name': 'Pavlov'}
# {'main_id': 226927713, 'id_friend': 318266203, 'first_name': 'Evgeny', 'last_name': 'Sinitsyn'}
# {'main_id': 226927713, 'id_friend': 483037058, 'first_name': 'Gans', 'last_name': 'Lindkhart'}
# {'main_id': 226927713, 'id_friend': 221359149, 'first_name': 'Gleb', 'last_name': 'Protsenko'}
# {'main_id': 226927713, 'id_friend': 116556411, 'first_name': 'Igor', 'last_name': 'Andryukov'}
# {'main_id': 226927713, 'id_friend': 203309613, 'first_name': 'Igor', 'last_name': 'Isaev'}
# {'main_id': 226927713, 'id_friend': 225067605, 'first_name': 'Ilya', 'last_name': 'Demin'}
# {'main_id': 226927713, 'id_friend': 233811937, 'first_name': 'Ilya', 'last_name': 'Dunaevsky'}
# {'main_id': 226927713, 'id_friend': 218644757, 'first_name': 'Ilya', 'last_name': 'Larichev'}
# Доступ к странице пользователя недоступен
# Shatalov
# Доступ к странице пользователя недоступен
# Kasyan
# Доступ к странице пользователя недоступен
# Matveeva
# {'main_id': 226927713, 'id_friend': 82190378, 'first_name': 'Kirill', 'last_name': 'Poroshkin'}
# {'main_id': 226927713, 'id_friend': 718641094, 'first_name': 'Klavdia', 'last_name': 'Lukashevich'}
# {'main_id': 226927713, 'id_friend': 209580238, 'first_name': 'Kostya', 'last_name': 'Fakaly'}
# Доступ к странице пользователя недоступен
# Senina
# {'main_id': 226927713, 'id_friend': 590787437, 'first_name': 'Ksenia', 'last_name': 'Guschanskaya'}
# {'main_id': 226927713, 'id_friend': 161647711, 'first_name': 'Ksenia', 'last_name': 'Ivanova'}
# Доступ к странице пользователя недоступен
# Panina
# {'main_id': 226927713, 'id_friend': 194688467, 'first_name': 'Ksenia', 'last_name': 'Rudomyotova'}
# Доступ к странице пользователя недоступен
# Xxxx
# {'main_id': 226927713, 'id_friend': 198418962, 'first_name': 'Lilia', 'last_name': 'Lovkova'}
# {'main_id': 226927713, 'id_friend': 206111473, 'first_name': 'Maria', 'last_name': 'Mitina'}
# Доступ к странице пользователя недоступен
# Shebek
# {'main_id': 226927713, 'id_friend': 696214649, 'first_name': 'Masha', 'last_name': 'Razbezhkina'}
# {'main_id': 226927713, 'id_friend': 620550778, 'first_name': 'Masha', 'last_name': 'Slizskaya'}
# Доступ к странице пользователя недоступен
# Kuzin
# {'main_id': 226927713, 'id_friend': 113001678, 'first_name': 'Maxim', 'last_name': 'Margolin'}
# {'main_id': 226927713, 'id_friend': 150897205, 'first_name': 'Maxim', 'last_name': 'Pogodin'}
# Доступ к странице пользователя недоступен
# Stepanov
# {'main_id': 226927713, 'id_friend': 280173352, 'first_name': 'Mikhail', 'last_name': 'Fursov'}
# {'main_id': 226927713, 'id_friend': 478068760, 'first_name': 'Milana', 'last_name': 'Inshakova'}
# {'main_id': 226927713, 'id_friend': 300548309, 'first_name': 'Milena', 'last_name': 'Khachatryan'}
# {'main_id': 226927713, 'id_friend': 138734902, 'first_name': 'Misha', 'last_name': 'Kryuchkov'}
# Доступ к странице пользователя недоступен
# Kober
# {'main_id': 226927713, 'id_friend': 681165800, 'first_name': 'Nastya', 'last_name': 'Lipina'}
# {'main_id': 226927713, 'id_friend': 571045725, 'first_name': 'Nastya', 'last_name': 'Prudnikova'}
# {'main_id': 226927713, 'id_friend': 718218200, 'first_name': 'Natalia', 'last_name': 'Isakova'}
# {'main_id': 226927713, 'id_friend': 156542071, 'first_name': 'Natalia', 'last_name': 'Isakova'}
# {'main_id': 226927713, 'id_friend': 236861483, 'first_name': 'Natasha', 'last_name': 'Shaparina'}
# {'main_id': 226927713, 'id_friend': 658012441, 'first_name': 'Nika', 'last_name': 'Lipina'}
# {'main_id': 226927713, 'id_friend': 87846703, 'first_name': 'Nikita', 'last_name': 'Karavaev'}
# {'main_id': 226927713, 'id_friend': 466731104, 'first_name': 'Nikita', 'last_name': 'Korotkov'}
# {'main_id': 226927713, 'id_friend': 242456434, 'first_name': 'Nikita', 'last_name': 'Kravtsov'}
# {'main_id': 226927713, 'id_friend': 615487948, 'first_name': 'Nikita', 'last_name': 'Latalin'}
# {'main_id': 226927713, 'id_friend': 271686363, 'first_name': 'Nikita', 'last_name': 'Paschenko'}
# {'main_id': 226927713, 'id_friend': 315789724, 'first_name': 'Olesya', 'last_name': 'Slizskaya'}
# {'main_id': 226927713, 'id_friend': 66211483, 'first_name': 'Pavel', 'last_name': 'Bardin'}
# {'main_id': 226927713, 'id_friend': 232407538, 'first_name': 'Pavel', 'last_name': 'Eremin'}
# Доступ к странице пользователя недоступен
# Svidersky
# {'main_id': 226927713, 'id_friend': 28984286, 'first_name': 'Rasul', 'last_name': 'Khaitov'}
# {'main_id': 226927713, 'id_friend': 276317484, 'first_name': 'Roman', 'last_name': 'Guk'}
# {'main_id': 226927713, 'id_friend': 435967876, 'first_name': 'Sara', 'last_name': 'Broyde'}
# Доступ к странице пользователя недоступен
# Frenkel
# Доступ к странице пользователя недоступен
# Satanovsky
# {'main_id': 226927713, 'id_friend': 125580252, 'first_name': 'Semyon', 'last_name': 'Smirnov'}
# {'main_id': 226927713, 'id_friend': 520340505, 'first_name': 'Shatskova', 'last_name': 'Arina'}
# {'main_id': 226927713, 'id_friend': 472644987, 'first_name': 'Show', 'last_name': 'Leopard'}
# {'main_id': 226927713, 'id_friend': 448445003, 'first_name': 'Stanislav', 'last_name': 'Afinogenov'}
# {'main_id': 226927713, 'id_friend': 366219792, 'first_name': 'Sveta', 'last_name': 'Rozhnyakova'}
# {'main_id': 226927713, 'id_friend': 247921456, 'first_name': 'Tanya', 'last_name': 'Kochetkova'}
# Доступ к странице пользователя недоступен
# Menschikov
# {'main_id': 226927713, 'id_friend': 454476840, 'first_name': 'Timur', 'last_name': 'Surnakov'}
# {'main_id': 226927713, 'id_friend': 163192338, 'first_name': 'Tolik', 'last_name': 'Tikhonov'}
# {'main_id': 226927713, 'id_friend': 395287803, 'first_name': 'Ulyana', 'last_name': 'Agafonova'}
# {'main_id': 226927713, 'id_friend': 222006397, 'first_name': 'Ulyana', 'last_name': 'Strelkova'}
# {'main_id': 226927713, 'id_friend': 80120898, 'first_name': 'Vanya', 'last_name': 'Pimenov'}
# Доступ к странице пользователя недоступен
# Pikalova
# {'main_id': 226927713, 'id_friend': 406309631, 'first_name': 'Veronika', 'last_name': 'Skorik'}
# {'main_id': 226927713, 'id_friend': 152276516, 'first_name': 'Vika', 'last_name': 'Selivanova'}
# {'main_id': 226927713, 'id_friend': 171430093, 'first_name': 'Viktoria', 'last_name': 'Isaenko'}
# Доступ к странице пользователя недоступен
# Onegina
# {'main_id': 226927713, 'id_friend': 215290600, 'first_name': 'Vlad', 'last_name': 'Korolyov'}
# Доступ к странице пользователя недоступен
# Murov
# {'main_id': 226927713, 'id_friend': 16237255, 'first_name': 'Vlad', 'last_name': 'Pronichev'}
# {'main_id': 226927713, 'id_friend': 560278882, 'first_name': 'Vlad', 'last_name': 'Razbezhkin'}
# {'main_id': 226927713, 'id_friend': 232023520, 'first_name': 'Vlad', 'last_name': 'Razbezhkin'}
# {'main_id': 226927713, 'id_friend': 260490212, 'first_name': 'Vlad', 'last_name': 'Ryabokon'}
# Доступ к странице пользователя недоступен
# Bishmenev
# {'main_id': 226927713, 'id_friend': 200187861, 'first_name': 'Vladislav', 'last_name': 'Zhigulsky'}
# {'main_id': 226927713, 'id_friend': 194620218, 'first_name': 'Vyacheslav', 'last_name': 'Viktorovich'}
# Доступ к странице пользователя недоступен
# Alexeev
# {'main_id': 226927713, 'id_friend': 328935848, 'first_name': 'Yuliana', 'last_name': 'Voytovich'}
# Доступ к странице пользователя недоступен
# Shuvalova
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - banned
# Сработало исключение - deleted
#         main_id  id_friend  first_name    last_name
# 0     113001678  124652274   Alexander   Govorukhin
# 1     113001678  211137990   Anastasia     Fedorova
# 2     113001678  181948702      Andrey       Maslov
# 3     113001678   34008823       Arsen    Zinchenko
# 4     113001678  229491502       Artem    Kurnenkov
# ...         ...        ...         ...          ...
# 4371  226927713  232023520        Vlad   Razbezhkin
# 4372  226927713  260490212        Vlad     Ryabokon
# 4373  226927713  200187861   Vladislav    Zhigulsky
# 4374  226927713  194620218  Vyacheslav  Viktorovich
# 4375  226927713  328935848     Yuliana    Voytovich
#
# [4376 rows x 4 columns]
# 182297238
# {'response': {'count': 131, 'items': [{'id': 581054682, 'nickname': '', 'track_code': '55f74565LuLRovDNRDfGqGjfg5Q9zUmT3ROm8ES7-DP6ODamTT9Did-bzc1PNc6lXBR8V4ihOofEH7GeIMin', 'first_name': '叫张', 'last_name': '志', 'can_access_closed': True, 'is_closed': False}, {'id': 351716742, 'nickname': '', 'track_code': 'f90d7147UyJuwR6JjqXL7aYcHlvfyB4eik7plmkJDuwQDhUDxQk-SWf3ItmIpcnlkdbtmGqkbQqTQv74DXpR', 'first_name': 'Alexander', 'last_name': 'Burasov', 'can_access_closed': True, 'is_closed': False}, {'id': 270847599, 'nickname': '', 'track_code': 'ca5d9579X0TfaZw_SZyqvTU1Ux0d_V4MA8Vp0V3ZwiGTmbK2g9oyL41Yoz0Ynfa5AP2t1aiRLRgayX6_Oaqd', 'first_name': 'Alexander', 'last_name': 'Gutsu', 'can_access_closed': False, 'is_closed': True}, {'id': 413192892, 'nickname': '', 'track_code': 'af6d7952go_ajF0OsDIEbAQUh8Swb5O4E4m-2aSe3CyIBWmcdYHv5IPvZQyxY1A0NdF5BwUD4KwKham3wO2D', 'first_name': 'Alexander', 'last_name': 'Kutyev', 'can_access_closed': False, 'is_closed': True}, {'id': 189683483, 'nickname': '', 'track_code': '8989428bBeDY2yrHq7Z95mohJhKpnV7ne7l8nl3cNxTWlp5hPpBoi4rvEpem6Xy6XejZ0BzxLfNitWvwOa9o', 'first_name': 'Alexander', 'last_name': 'Pogulyay', 'can_access_closed': True, 'is_closed': False}, {'id': 191447301, 'nickname': '', 'track_code': '6497b6f4uTu9tCHbPMOnSOE7_x09BFztyk0pPYXRZDfE48uxBHrUUObXS9M8l6Ua0_UI3YhoL_nTQT5T4aI7', 'first_name': 'Alexander', 'last_name': 'Prusakov', 'can_access_closed': False, 'is_closed': True}, {'id': 166129153, 'nickname': '', 'track_code': '10c613a5Dw-KopYGzc0wlXDSIYanTRGNTZzge9aXNLKZwB1fSh5iZNmTrASYzWPBTx7TRBIhYplUkPcVsuRr', 'first_name': 'Alexander', 'last_name': 'Strety', 'can_access_closed': False, 'is_closed': True}, {'id': 191960247, 'nickname': '', 'track_code': '7fad6295wxcYzkkHpQ_OJgMHUUIBKCmUowQyBq08XA1srD7UrmeufEX-clWpX5UpNMiihLREWoC6CCVoyU8D', 'first_name': 'Alexander', 'last_name': 'Volkov', 'can_access_closed': True, 'is_closed': False}, {'id': 11630732, 'nickname': '', 'track_code': '50b13927ANF4Jel12tfx2VtMZnPHAge4a2cvqXs5WHa9MO7SbINtuiMX1SHe0aTZZIKThBliZ7V8fErHH0o', 'first_name': 'Alexandra', 'last_name': 'Rogozina', 'can_access_closed': True, 'is_closed': False}, {'id': 170447961, 'nickname': '', 'track_code': 'df1f4936yTZNzSBZHfDpg3MHkIirlCsHxsNm4Lu-8o5d4XUAti2kXUP9GQkd876GTcNhSB74WBPfz3GO382t', 'first_name': 'Alexey', 'last_name': 'Kondyrev', 'can_access_closed': False, 'is_closed': True}, {'id': 152430906, 'nickname': '', 'track_code': '138621b0T9NFedZhBElLHKhZ9t03oFaKN27DUlGEhIUBvQHlccwiuBdBuzUFHxwZkp0BGoLMJZ4uYtQ8Nffb', 'first_name': 'Alexey', 'last_name': 'Petukhov', 'can_access_closed': True, 'is_closed': False}, {'id': 19746428, 'nickname': 'アレクセ', 'track_code': 'bdabb90cNii8q37NLJd85RKEDJ9Q-j_iav02hK31h1N26TjQW15bQ-CcT8ktkXmyLUvzaI6aX-995lPqyYY', 'first_name': 'Alexey', 'last_name': 'Semichev', 'can_access_closed': True, 'is_closed': False}, {'id': 223264493, 'nickname': '', 'track_code': '1421ca52fcEJrJAI3ZtarVgoUV5xbGsFtKjREJOvwC9IY_WvPPEQqlOY_wzbylj_YOGvnMQAGBGtpMZ-99yf', 'first_name': 'Alina', 'last_name': 'Latypova', 'can_access_closed': False, 'is_closed': True}, {'id': 215845094, 'nickname': '', 'track_code': '4c99ebf9xLtaPF9a1nOiZlQP-WrxwvoUanUcBONd2wsAq0ZuqKip0FQNbwrfdv83bMIHr0SuiQBzeQtqhy6E', 'first_name': 'Alina', 'last_name': 'Mirnaya', 'can_access_closed': True, 'is_closed': False}, {'id': 286533486, 'nickname': '', 'track_code': '53e4e700Wn0dHIkaTBoSsKesP8SBc8Dsnoqx2niX_dFvhs_dnNU3FkJ5sk4RTxC6mmXAAzQfs_iHhqa0HOSi', 'first_name': 'Alinka', 'last_name': 'Zimina', 'can_access_closed': True, 'is_closed': False}, {'id': 160477894, 'nickname': 'Yuryevna', 'track_code': '116f1898Pa68PIBTlqEo-pjLj5W7zRuMcShNZJFkXTK_9SA6a_9QxbQP7VKVpyuroA5xUA6haJhoJFoK9RcC', 'first_name': 'Anastasia', 'last_name': 'Mitrofanova', 'can_access_closed': True, 'is_closed': False}, {'id': 152856551, 'nickname': '', 'track_code': '0dc56b17d5C_Iy2c2xVsSrAXtkVKgeYXwcMjw4DvX24oK7f2VkAa--FARc7eEGAdlt9Ehf_tlQPYzzSt5JwA', 'first_name': 'Anastasia', 'last_name': 'Sitnova', 'can_access_closed': True, 'is_clos ...
# {'main_id': 182297238, 'id_friend': 581054682, 'first_name': '叫张', 'last_name': '志'}
# {'main_id': 182297238, 'id_friend': 351716742, 'first_name': 'Alexander', 'last_name': 'Burasov'}
# Доступ к странице пользователя недоступен
# Gutsu
# Доступ к странице пользователя недоступен
# Kutyev
# {'main_id': 182297238, 'id_friend': 189683483, 'first_name': 'Alexander', 'last_name': 'Pogulyay'}
# Доступ к странице пользователя недоступен
# Prusakov
# Доступ к странице пользователя недоступен
# Strety
# {'main_id': 182297238, 'id_friend': 191960247, 'first_name': 'Alexander', 'last_name': 'Volkov'}
# {'main_id': 182297238, 'id_friend': 11630732, 'first_name': 'Alexandra', 'last_name': 'Rogozina'}
# Доступ к странице пользователя недоступен
# Kondyrev
# {'main_id': 182297238, 'id_friend': 152430906, 'first_name': 'Alexey', 'last_name': 'Petukhov'}
# {'main_id': 182297238, 'id_friend': 19746428, 'first_name': 'Alexey', 'last_name': 'Semichev'}
# Доступ к странице пользователя недоступен
# Latypova
# {'main_id': 182297238, 'id_friend': 215845094, 'first_name': 'Alina', 'last_name': 'Mirnaya'}
# {'main_id': 182297238, 'id_friend': 286533486, 'first_name': 'Alinka', 'last_name': 'Zimina'}
# {'main_id': 182297238, 'id_friend': 160477894, 'first_name': 'Anastasia', 'last_name': 'Mitrofanova'}
# {'main_id': 182297238, 'id_friend': 152856551, 'first_name': 'Anastasia', 'last_name': 'Sitnova'}
# {'main_id': 182297238, 'id_friend': 192003496, 'first_name': 'Andrey', 'last_name': 'Aritonov'}
# {'main_id': 182297238, 'id_friend': 189107919, 'first_name': 'Andrey', 'last_name': 'Belashenko'}
# {'main_id': 182297238, 'id_friend': 278524645, 'first_name': 'Andrey', 'last_name': 'Guzeev'}
# {'main_id': 182297238, 'id_friend': 238104527, 'first_name': 'Andrey', 'last_name': 'Kleonsky'}
# {'main_id': 182297238, 'id_friend': 181948702, 'first_name': 'Andrey', 'last_name': 'Maslov'}
# Доступ к странице пользователя недоступен
# Stanislavovich
# {'main_id': 182297238, 'id_friend': 530470435, 'first_name': 'Angry', 'last_name': 'Sharrke'}
# {'main_id': 182297238, 'id_friend': 168357108, 'first_name': 'Anna', 'last_name': 'Borisova'}
# {'main_id': 182297238, 'id_friend': 216934975, 'first_name': 'Anna', 'last_name': 'Medvedeva'}
# {'main_id': 182297238, 'id_friend': 174132769, 'first_name': 'Anton', 'last_name': 'Agafonov'}
# {'main_id': 182297238, 'id_friend': 219362200, 'first_name': 'Anya', 'last_name': 'Fedulova'}
# {'main_id': 182297238, 'id_friend': 229491502, 'first_name': 'Artem', 'last_name': 'Kurnenkov'}
# {'main_id': 182297238, 'id_friend': 567862992, 'first_name': 'Artem', 'last_name': 'Neizvestny'}
# {'main_id': 182297238, 'id_friend': 160337615, 'first_name': 'Artem', 'last_name': 'Novikov'}
# ...
# {'main_id': 151553493, 'id_friend': 132020865, 'first_name': 'Olga', 'last_name': 'Seredina'}
# Доступ к странице пользователя недоступен
# Vladimirskaya
# {'main_id': 151553493, 'id_friend': 173657741, 'first_name': 'Olga', 'last_name': 'Yaloletdinova'}
# {'main_id': 151553493, 'id_friend': 381371269, 'first_name': 'Olya', 'last_name': 'Rakhimova'}
# Доступ к странице пользователя недоступен
# Vokhidov
# {'main_id': 151553493, 'id_friend': 91120577, 'first_name': 'Pavel', 'last_name': 'Dmitriev'}
# Доступ к странице пользователя недоступен
# Gorelov
# {'main_id': 151553493, 'id_friend': 2448220, 'first_name': 'Pavel', 'last_name': 'Gorenkov'}
# Доступ к странице пользователя недоступен
# Sakanov
# Доступ к странице пользователя недоступен
# Smerkalov
# {'main_id': 151553493, 'id_friend': 138976508, 'first_name': 'Pavel', 'last_name': 'Vasilyev'}
# {'main_id': 151553493, 'id_friend': 736029895, 'first_name': 'Pilki', 'last_name': 'Studia-Manikyura'}
# {'main_id': 151553493, 'id_friend': 330518238, 'first_name': 'Polina', 'last_name': 'Kulenko'}
# {'main_id': 151553493, 'id_friend': 365685566, 'first_name': 'Polina', 'last_name': 'Podvolotskaya'}
# Доступ к странице пользователя недоступен
# Nastya
# {'main_id': 151553493, 'id_friend': 562109815, 'first_name': 'Qbilay', 'last_name': 'Ö'}
# {'main_id': 151553493, 'id_friend': 733992544, 'first_name': 'Relaxso', 'last_name': 'Relaxso'}
# {'main_id': 151553493, 'id_friend': 532851478, 'first_name': 'Rimma', 'last_name': 'Dmitrieva'}
# {'main_id': 151553493, 'id_friend': 41883031, 'first_name': 'Roma', 'last_name': 'Kulpin'}
# Доступ к странице пользователя недоступен
# Borodkin
# Доступ к странице пользователя недоступен
# Kulpin
# {'main_id': 151553493, 'id_friend': 290715540, 'first_name': 'Ruslan', 'last_name': 'Komarov'}
# {'main_id': 151553493, 'id_friend': 154353414, 'first_name': 'Ruslan', 'last_name': 'Komarov'}
# {'main_id': 151553493, 'id_friend': 86135972, 'first_name': 'Sanek', 'last_name': 'Killer'}
# Доступ к странице пользователя недоступен
# Gerasimov
# Доступ к странице пользователя недоступен
# Pankratov
# {'main_id': 151553493, 'id_friend': 213554718, 'first_name': 'Serezha', 'last_name': 'Gusev'}
# {'main_id': 151553493, 'id_friend': 490108097, 'first_name': 'Sergey', 'last_name': 'Cher'}
# {'main_id': 151553493, 'id_friend': 411643758, 'first_name': 'Sergey', 'last_name': 'Dunets'}
# {'main_id': 151553493, 'id_friend': 575416314, 'first_name': 'Sergey', 'last_name': 'Familia'}
# {'main_id': 151553493, 'id_friend': 298153150, 'first_name': 'Sergey', 'last_name': 'Films'}
# {'main_id': 151553493, 'id_friend': 248936905, 'first_name': 'Sergey', 'last_name': 'Martyanov'}
# {'main_id': 151553493, 'id_friend': 353216672, 'first_name': 'Sergey', 'last_name': 'Medvedev'}
# {'main_id': 151553493, 'id_friend': 290465450, 'first_name': 'Sergey', 'last_name': 'Nesterov'}
# {'main_id': 151553493, 'id_friend': 254337077, 'first_name': 'Sergey', 'last_name': 'Rogozhin'}
# {'main_id': 151553493, 'id_friend': 305032981, 'first_name': 'Sergey', 'last_name': 'Romanov'}
# {'main_id': 151553493, 'id_friend': 336098841, 'first_name': 'Sergey', 'last_name': 'Sergeev'}
# {'main_id': 151553493, 'id_friend': 387842392, 'first_name': 'Sergey', 'last_name': 'Shibaev'}
# Доступ к странице пользователя недоступен
# Strogy
# Доступ к странице пользователя недоступен
# Tarasov
# {'main_id': 151553493, 'id_friend': 336513703, 'first_name': 'Sergey', 'last_name': 'Trofimov'}
# Доступ к странице пользователя недоступен
# Tunkin
# {'main_id': 151553493, 'id_friend': 153657215, 'first_name': 'Sergey', 'last_name': 'Volkov'}
# {'main_id': 151553493, 'id_friend': 449881297, 'first_name': 'Sergey', 'last_name': 'Yashkov'}
# {'main_id': 151553493, 'id_friend': 154255966, 'first_name': 'Stanislav', 'last_name': 'Makarov'}
# Доступ к странице пользователя недоступен
# Vladimirovich
# {'main_id': 151553493, 'id_friend': 509857713, 'first_name': 'Studio', 'last_name': 'People'}
# {'main_id': 151553493, 'id_friend': 491275207, 'first_name': 'Svetlana', 'last_name': 'Kochetkova'}
# {'main_id': 151553493, 'id_friend': 209548346, 'first_name': 'Svetlana', 'last_name': 'Makhankova'}
# {'main_id': 151553493, 'id_friend': 70538188, 'first_name': 'Svetlana', 'last_name': 'Sokolova'}
# {'main_id': 151553493, 'id_friend': 184670242, 'first_name': 'Svetlana', 'last_name': 'Svetlova'}
# {'main_id': 151553493, 'id_friend': 389563998, 'first_name': 'Svetlana', 'last_name': 'Vladimirova'}
# {'main_id': 151553493, 'id_friend': 197019365, 'first_name': 'Svetlana', 'last_name': 'Zubkova'}
# Доступ к странице пользователя недоступен
# Zubkova
# {'main_id': 151553493, 'id_friend': 108113847, 'first_name': 'Svetlanka', 'last_name': 'Nosova'}
# Доступ к странице пользователя недоступен
# Nesterova
# {'main_id': 151553493, 'id_friend': 142259390, 'first_name': 'Tanechka', 'last_name': 'Novikova'}
# {'main_id': 151553493, 'id_friend': 166345277, 'first_name': 'Tanya', 'last_name': 'Cherkasova'}
# {'main_id': 151553493, 'id_friend': 4604456, 'first_name': 'Tanya', 'last_name': 'Tanya'}
# {'main_id': 151553493, 'id_friend': 204752144, 'first_name': 'Tanyushka', 'last_name': 'Pavlova'}
# {'main_id': 151553493, 'id_friend': 288310717, 'first_name': 'Tatyana', 'last_name': 'Abashkina'}
# {'main_id': 151553493, 'id_friend': 67539285, 'first_name': 'Tatyana', 'last_name': 'Andreeva'}
# Доступ к странице пользователя недоступен
# Bolshakova
# Доступ к странице пользователя недоступен
# Chizhova
# Доступ к странице пользователя недоступен
# Esikova
# Доступ к странице пользователя недоступен
# Fedorova
# Доступ к странице пользователя недоступен
# Ivanovskaya
# Доступ к странице пользователя недоступен
# Klevakina
# Доступ к странице пользователя недоступен
# Materukhina
# Доступ к странице пользователя недоступен
# Maximova
# Доступ к странице пользователя недоступен
# Narozhnaya
# {'main_id': 151553493, 'id_friend': 345703031, 'first_name': 'Tatyana', 'last_name': 'Natalina'}
# Доступ к странице пользователя недоступен
# Noskova
# Доступ к странице пользователя недоступен
# Polyakova
# {'main_id': 151553493, 'id_friend': 478262289, 'first_name': 'Tatyana', 'last_name': 'Sakharnaya'}
# {'main_id': 151553493, 'id_friend': 174831337, 'first_name': 'Tatyana', 'last_name': 'Sazhina'}
# {'main_id': 151553493, 'id_friend': 669372001, 'first_name': 'Tatyana', 'last_name': 'Shvayko'}
# {'main_id': 151553493, 'id_friend': 74026217, 'first_name': 'Tatyanka', 'last_name': 'Vinogradova'}
# {'main_id': 151553493, 'id_friend': 8104091, 'first_name': 'Timofey', 'last_name': 'Goryachev'}
# {'main_id': 151553493, 'id_friend': 713887980, 'first_name': 'Tolani', 'last_name': 'Prakash'}
# Доступ к странице пользователя недоступен
# Paneva
# {'main_id': 151553493, 'id_friend': 169606064, 'first_name': 'Vadim', 'last_name': 'Alexeevich'}
# {'main_id': 151553493, 'id_friend': 54341868, 'first_name': 'Vadim', 'last_name': 'Stogov'}
# {'main_id': 151553493, 'id_friend': 68186109, 'first_name': 'Valentin', 'last_name': 'Gruzdev'}
# Доступ к странице пользователя недоступен
# Ananyeva
# Доступ к странице пользователя недоступен
# Sushkova
# {'main_id': 151553493, 'id_friend': 475061065, 'first_name': 'Valeria', 'last_name': 'Vladimirovna'}
# {'main_id': 151553493, 'id_friend': 144516622, 'first_name': 'Varvara', 'last_name': 'Krutina'}
# {'main_id': 151553493, 'id_friend': 202331364, 'first_name': 'Varya', 'last_name': 'Belova'}
# {'main_id': 151553493, 'id_friend': 76036151, 'first_name': 'Vera', 'last_name': 'Galkina'}
# {'main_id': 151553493, 'id_friend': 521384448, 'first_name': 'Veranda', 'last_name': 'Lounge'}
# {'main_id': 151553493, 'id_friend': 134212516, 'first_name': 'Veronika', 'last_name': 'Barnyagina'}
# {'main_id': 151553493, 'id_friend': 637340883, 'first_name': 'Viki', 'last_name': 'Kameneva'}
# {'main_id': 151553493, 'id_friend': 31390085, 'first_name': 'Viktor', 'last_name': 'Makhalov'}
# {'main_id': 151553493, 'id_friend': 161408147, 'first_name': 'Viktor', 'last_name': 'Zaytsev'}
# Доступ к странице пользователя недоступен
# Basaeva
# {'main_id': 151553493, 'id_friend': 426185694, 'first_name': 'Viktoria', 'last_name': 'Daymond--Vladimir'}
# {'main_id': 151553493, 'id_friend': 451005310, 'first_name': 'Viktoria', 'last_name': 'Klevtsova'}
# {'main_id': 151553493, 'id_friend': 500786587, 'first_name': 'Viktoria', 'last_name': 'Kurakina'}
# {'main_id': 151553493, 'id_friend': 133352286, 'first_name': 'Viktoria', 'last_name': 'Lukina'}
# {'main_id': 151553493, 'id_friend': 431775553, 'first_name': 'Viktoria', 'last_name': 'Lukina'}
# Доступ к странице пользователя недоступен
# Molkova
# Доступ к странице пользователя недоступен
# Pavelina
# {'main_id': 151553493, 'id_friend': 88760309, 'first_name': 'Viktoria', 'last_name': 'Petrushkina'}
# {'main_id': 151553493, 'id_friend': 308308680, 'first_name': 'Viktoria', 'last_name': 'Savinova'}
# {'main_id': 151553493, 'id_friend': 53399404, 'first_name': 'Viktoria', 'last_name': 'Torkhunova'}
# Доступ к странице пользователя недоступен
# Varlamova
# {'main_id': 151553493, 'id_friend': 51595165, 'first_name': 'Viktoria', 'last_name': 'Vilkova'}
# {'main_id': 151553493, 'id_friend': 481328217, 'first_name': 'Viktoria', 'last_name': 'Vladimirovna'}
# {'main_id': 151553493, 'id_friend': 368543370, 'first_name': 'Viktoria', 'last_name': 'Volkova'}
# {'main_id': 151553493, 'id_friend': 283259482, 'first_name': 'Vikulya', 'last_name': 'Panfilova'}
# {'main_id': 151553493, 'id_friend': 184361850, 'first_name': 'Vikusya', 'last_name': 'Koroleva'}
# {'main_id': 151553493, 'id_friend': 166692951, 'first_name': 'Vlad', 'last_name': 'Olegov'}
# Доступ к странице пользователя недоступен
# Surnin
# {'main_id': 151553493, 'id_friend': 317142523, 'first_name': 'Vlada', 'last_name': 'Aleinikova'}
# {'main_id': 151553493, 'id_friend': 121704286, 'first_name': 'Vlada', 'last_name': 'Aleynikova'}
# {'main_id': 151553493, 'id_friend': 287206739, 'first_name': 'Vladimir', 'last_name': 'Izvilina'}
# {'main_id': 151553493, 'id_friend': 444073356, 'first_name': 'Vladimir', 'last_name': 'Nikitin'}
# {'main_id': 151553493, 'id_friend': 142031672, 'first_name': 'Vladimir', 'last_name': 'Prokhorov'}
# Доступ к странице пользователя недоступен
# Malinina-Kostakova
# {'main_id': 151553493, 'id_friend': 373979812, 'first_name': 'Vova', 'last_name': 'Savko'}
# {'main_id': 151553493, 'id_friend': 324986187, 'first_name': 'Vusal', 'last_name': 'Farhadli'}
# {'main_id': 151553493, 'id_friend': 119707068, 'first_name': 'Yana', 'last_name': 'Fomina'}
# {'main_id': 151553493, 'id_friend': 66511388, 'first_name': 'Yana', 'last_name': 'Repina'}
# {'main_id': 151553493, 'id_friend': 469290130, 'first_name': 'Yaroslavl', 'last_name': 'Kontsert'}
# Доступ к странице пользователя недоступен
# Borisovna
# Доступ к странице пользователя недоступен
# Efimova
# {'main_id': 151553493, 'id_friend': 318041788, 'first_name': 'Yulia', 'last_name': 'Klimina'}
# {'main_id': 151553493, 'id_friend': 363203858, 'first_name': 'Yulia', 'last_name': 'Lantseva'}
# {'main_id': 151553493, 'id_friend': 45828431, 'first_name': 'Yulia', 'last_name': 'Loseva'}
# {'main_id': 151553493, 'id_friend': 512120457, 'first_name': 'Yulia', 'last_name': 'Multyashnaya'}
# Доступ к странице пользователя недоступен
# Nikanorova
# Доступ к странице пользователя недоступен
# Nikitina
# {'main_id': 151553493, 'id_friend': 5586773, 'first_name': 'Yulia', 'last_name': 'Pichugina'}
# {'main_id': 151553493, 'id_friend': 95259209, 'first_name': 'Yulia', 'last_name': 'Seltsova'}
# {'main_id': 151553493, 'id_friend': 324295259, 'first_name': 'Yulia', 'last_name': 'Shatunova'}
# {'main_id': 151553493, 'id_friend': 469373172, 'first_name': 'Yulia', 'last_name': 'Sidelka'}
# {'main_id': 151553493, 'id_friend': 100657643, 'first_name': 'Yulya', 'last_name': 'Pikalyova'}
# {'main_id': 151553493, 'id_friend': 108212750, 'first_name': 'Yulya', 'last_name': 'Zagrebina'}
# {'main_id': 151553493, 'id_friend': 480610115, 'first_name': 'Zakhar', 'last_name': 'Ravshanovich'}
# Доступ к странице пользователя недоступен
# Ibragimov
# {'main_id': 151553493, 'id_friend': 98082395, 'first_name': 'Zhanna', 'last_name': 'Molkova'}
# Доступ к странице пользователя недоступен
# Kalanin
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - deleted
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - deleted
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - deleted
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - deleted
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - deleted
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
# Сработало исключение - banned
#         main_id  id_friend first_name     last_name
# 0     113001678  124652274  Alexander    Govorukhin
# 1     113001678  211137990  Anastasia      Fedorova
# 2     113001678  181948702     Andrey        Maslov
# 3     113001678   34008823      Arsen     Zinchenko
# 4     113001678  229491502      Artem     Kurnenkov
# ...         ...        ...        ...           ...
# 6657  151553493  469373172      Yulia       Sidelka
# 6658  151553493  100657643      Yulya     Pikalyova
# 6659  151553493  108212750      Yulya     Zagrebina
# 6660  151553493  480610115     Zakhar  Ravshanovich
# 6661  151553493   98082395     Zhanna       Molkova
#
# [6662 rows x 4 columns]
#         main_id  id_friend first_name     last_name
# 0     113001678  124652274  Alexander    Govorukhin
# 1     113001678  211137990  Anastasia      Fedorova
# 2     113001678  181948702     Andrey        Maslov
# 3     113001678   34008823      Arsen     Zinchenko
# 4     113001678  229491502      Artem     Kurnenkov
# ...         ...        ...        ...           ...
# 6657  151553493  469373172      Yulia       Sidelka
# 6658  151553493  100657643      Yulya     Pikalyova
# 6659  151553493  108212750      Yulya     Zagrebina
# 6660  151553493  480610115     Zakhar  Ravshanovich
# 6661  151553493   98082395     Zhanna       Molkova
#
# [6662 rows x 4 columns]

# %%
infoUser = {'id_firstNode':[],'id_secondNode':[],'CountOfCommonFriend':[]}

frame3 = pd.DataFrame([infoUser])
frame3 = frame3.iloc[0:0] #Создаем новый DataFrame в котором будут храниться люди с общими друзьями 

countOfMainID = len(frame2.main_id.unique())#Считаем сколько уникальных id хранятся в поле main_id
i = 0
j = 0

current_firstNodeId  = frame2.main_id.unique() #Здесь хранятся id пользователей чьих друзей запишут в data1FriendFirstNode 

while countOfMainID > i:
  
  data1FriendFirstNode = frame2.loc[current_firstNodeId[i] == frame2.main_id, 'id_friend'].to_list() #Записываем друзей пользователя i-го порядка 
  countOfFirstNodeId = len(data1FriendFirstNode) #Находим количество его друзей 
  while countOfFirstNodeId > j:
    countOfCommonFriend = 0 #Создаем переменную для подсчета совпадающих друзей
    data2FriendSecondNode = frame2.loc[data1FriendFirstNode[j] == frame2.main_id, 'id_friend'].to_list() #Здесь хранятся id пользователей друзей, чтобы затем определить между ними общих
    current_SecondNodeId  = len(data2FriendSecondNode) #Находим друзей пользователя j-го порядка
    sizedata1 = len(data1FriendFirstNode) #Вычисляем количество друзей i-го пользователя
    sizedata2 = len(data2FriendSecondNode)#Вычисляем количество друзей j-го пользователя
    for ix in range(sizedata1):
      for jx in range(sizedata2):
        if data1FriendFirstNode[ix] == data2FriendSecondNode[jx]:
          countOfCommonFriend += 1
          print()

    new_row = {'id_firstNode': current_firstNodeId[i], 'id_secondNode': data1FriendFirstNode[j],'CountOfCommonFriend': countOfCommonFriend}
    frame3 = frame3.append(new_row, ignore_index=True)
    j += 1
    
  i += 1
    
print(frame3)
# Out:
#     id_firstNode id_secondNode CountOfCommonFriend
# 0      113001678     124652274                  12
# 1      113001678     211137990                   5
# 2      113001678     181948702                  21
# 3      113001678      34008823                   4
# 4      113001678     229491502                   7
# ..           ...           ...                 ...
# 575     21789079      81529966                   0
# 576     21789079     691800424                   0
# 577     21789079      52540670                   0
# 578     21789079     242492713                   0
# 579     21789079      46100261                   0
#
# [580 rows x 3 columns]

# %%
frame4 = frame3.loc[frame3["CountOfCommonFriend"] > 0]

frame4 = frame4.drop_duplicates()
frame4
# Out:
#     id_firstNode id_secondNode CountOfCommonFriend
# 0      113001678     124652274                  12
# 1      113001678     211137990                   5
# 2      113001678     181948702                  21
# 3      113001678      34008823                   4
# 4      113001678     229491502                   7
# 6      113001678      39262511                   4
# 7      113001678     314194014                   1
# 8      113001678     149073861                   8
# 9      113001678     237842422                  13
# 10     113001678     377465565                  12
# 11     113001678     612202967                   2
# 12     113001678      15360494                   3
# 13     113001678     233210454                  11
# 14     113001678     135182205                   7
# 15     113001678     143779216                   9
# 16     113001678      21789079                   2
# 17     113001678     239772243                  12
# 18     113001678     181254379                   9
# 19     113001678     209218232                   5
# 20     113001678     180441581                   2
# 21     113001678     131765293                   6
# 22     113001678     116556411                   9
# 23     113001678     218644757                  13
# 24     113001678      18362790                   1
# 25     113001678     144789718                   7
# 27     113001678     189135415                  10
# 28     113001678      87456493                  10
# 29     113001678     226927713                   7
# 30     113001678     182297238                   6
# 31     113001678     206111473                  11
# 32     113001678      99467665                  10
# 33     113001678     101278964                  11
# 34     113001678     161594007                  17
# 36     113001678     152087036                   3
# 37     113001678     280173352                   9
# 38     113001678     369829012                   9
# 39     113001678      37816448                   4
# 40     113001678     621215806                   4
# 41     113001678     133224204                  11
# 42     113001678     163192338                  10
# 43     113001678      73182682                   7
# 44     113001678      54341868                   5
# 45     113001678     163312070                   6
# 46     113001678     124480381                   5
# 47     113001678      70098839                   6
# 48     113001678     151553493                   1
# 100    124652274     149073861                  13
# 114    124652274     377465565                   8
# 120    124652274     135182205                  24
# 165    124652274     116556411                  27
# 173    124652274     218644757                  25
# 209    124652274     226927713                  15
# 223    124652274     206111473                  73
# 227    124652274     101278964                  22
# 237    124652274     113001678                  12
# 245    124652274     280173352                   9
# 338    124652274     133224204                  18
# 353    124652274     163192338                  15
# 371    124652274     163312070                  13

# %%
G = nx.Graph()
id_firstNode = frame4.id_firstNode.to_list()
id_secondNode = frame4.id_secondNode.to_list()


sizeOfNodes = len(frame4.CountOfCommonFriend)
for ix in range(sizeOfNodes):
  G.add_edge(id_firstNode[ix],id_secondNode[ix])
  G.edges()
nx.draw(G, with_labels=1)
